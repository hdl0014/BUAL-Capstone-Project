# %% [markdown]
# # FastF1: 2018-2023 Race & Qualifying Data

# %%
import pandas as pd
import fastf1 as ff1

for year in range(2018, 2023):  
    for race in range(1, 23):
        try:
            # Qualifying sessions
            qualifying_session = ff1.get_session(year, str(race), '4')
            qualifying_session.load(telemetry=True, laps=True, weather=True)
            
            prefix = f'y{year}_r{race}'  
            exec(f'{prefix}qualLaps = qualifying_session.laps')
            exec(f'{prefix}qualWeather = qualifying_session.weather_data')
            exec(f'{prefix}qualCarData = qualifying_session.car_data')
            exec(f'{prefix}qualPos = qualifying_session.pos_data')
            exec(f'{prefix}qualResults = qualifying_session.results')
            exec(f'{prefix}qualStatus = qualifying_session.session_status')
            exec(f'{prefix}qualTrackStatus = qualifying_session.track_status')
            exec(f'{prefix}qualDrivers = qualifying_session.drivers')

            # Race sessions
            race_session = ff1.get_session(year, str(race), '5')
            race_session.load(telemetry=True, laps=True, weather=True)
            exec(f'{prefix}raceLaps = race_session.laps')
            exec(f'{prefix}raceWeather = race_session.weather_data')
            exec(f'{prefix}raceCarData = race_session.car_data')
            exec(f'{prefix}racePos = race_session.pos_data')
            exec(f'{prefix}raceResults = race_session.results')
            exec(f'{prefix}raceStatus = race_session.session_status')
            exec(f'{prefix}raceTrackStatus = race_session.track_status')
            exec(f'{prefix}raceDrivers = race_session.drivers')
        
        except KeyError:
            print(f"No data for year {year} race {race}")
            continue

            
            
#example: y2018_r11qualWeather is weather data from qualification round of the 11th race of 2018
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.1.2]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '7', '5', '33', '3', '20', '8', '27', '55', '77', '14', '2', '11', '18', '31', '28', '9', '16', '35', '10']
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.1.2]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# core        WARNING 	Car position data is unavailable!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 23
#      21 # Race sessions
#      22 race_session = ff1.get_session(year, str(race), '5')
# ---> 23 race_session.load(telemetry=True, laps=True, weather=True)
#      24 exec(f'{prefix}raceLaps = race_session.laps')
#      25 exec(f'{prefix}raceWeather = race_session.weather_data')
#
# File ~\anaconda3\Lib\site-packages\fastf1\core.py:1257, in Session.load(self, laps, telemetry, weather, messages, livedata)
#    1254     self._add_first_lap_time_from_ergast()
#    1256 if telemetry:
# -> 1257     self._load_telemetry(livedata=livedata)
#    1259 if weather:
#    1260     self._load_weather_data(livedata=livedata)
#
# File ~\anaconda3\Lib\site-packages\fastf1\logger.py:152, in soft_exceptions.<locals>.__decorator.<locals>.__wrapped(*args, **kwargs)
#     150 if not LoggingManager.debug:
#     151     try:
# --> 152         return func(*args, **kwargs)
#     153     except Exception as exc:
#     154         logger.warning(msg)
#
# File ~\anaconda3\Lib\site-packages\fastf1\core.py:2164, in Session._load_telemetry(self, livedata)
#    2161         drv_car['Date'] = drv_car['Date'].round('ms')
#    2163         drv_car['Time'] = drv_car['Date'] - self.t0_date
# -> 2164         drv_car['SessionTime'] = drv_car['Time']
#    2166         processed[drv] = drv_car
#    2168 if hasattr(self, '_laps'):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4910     return _reindex_for_setitem(value, self.index)
#    4911 elif is_dict_like(value):
# -> 4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
#    4915     com.require_length_match(value, self.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:12016, in _reindex_for_setitem(value, index)
#   12012 def _reindex_for_setitem(value: DataFrame | Series, index: Index) -> ArrayLike:
#   12013     # reindex if necessary
#   12015     if value.index.equals(index) or not len(index):
# > 12016         return value._values.copy()
#   12018     # GH#4107
#   12019     try:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:562, in DatetimeLikeArrayMixin.copy(self, order)
#     560 def copy(self: DatetimeLikeArrayT, order="C") -> DatetimeLikeArrayT:
#     561     # error: Unexpected keyword argument "order" for "copy"
# --> 562     new_obj = super().copy(order=order)  # type: ignore[call-arg]
#     563     new_obj._freq = self.freq
#     564     return new_obj
#
# KeyboardInterrupt:

# %%
# Creating a custom raceId based on year, race and type (qualifying or race)
def get_dynamic_df(year, race, postfix):
    try:
        df = globals()[f'y{year}_r{race}{postfix}']
        raceId = f'{year}r{race}' + ('q' if 'qual' in postfix else 'r')
        df['raceId'] = raceId  # Append raceId to the dataframe
        return df
    except KeyError:
        return None

    
# Function to concatenate data for a specific type and category
def concat_data(type_prefix, postfix):
    return pd.concat(
        [
            get_dynamic_df(year, race, f'{type_prefix}{postfix}')
            for year in range(2018, 2023)
            for race in range(1, 23)
            if get_dynamic_df(year, race, f'{type_prefix}{postfix}') is not None
        ],
        ignore_index=True
    )


# Concatenate qualifying data on top of eachother
all_qualLaps = concat_data('qual', 'Laps')
all_qualWeather = concat_data('qual', 'Weather')
all_qualResults = concat_data('qual', 'Results')
all_qualStatus = concat_data('qual', 'Status')
all_qualTrackStatus = concat_data('qual', 'TrackStatus')

# Concatenate race data on top of eachother
all_raceLaps = concat_data('race', 'Laps')
all_raceWeather = concat_data('race', 'Weather')
all_raceResults = concat_data('race', 'Results')
all_raceStatus = concat_data('race', 'Status')
all_raceTrackStatus = concat_data('race', 'TrackStatus')

# %%
# I think CarData, Pos, Drivers are dicts.

# %%
y2018_r8qualWeather.info()
all_qualWeather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           78 non-null     timedelta64[ns]
#  1   AirTemp        78 non-null     float64
#  2   Humidity       78 non-null     float64
#  3   Pressure       78 non-null     float64
#  4   Rainfall       78 non-null     bool
#  5   TrackTemp      78 non-null     float64
#  6   WindDirection  78 non-null     int64
#  7   WindSpeed      78 non-null     float64
#  8   raceId         78 non-null     object
# dtypes: bool(1), float64(5), int64(1), object(1), timedelta64[ns](1)
# memory usage: 5.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4514 entries, 0 to 4513
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           4514 non-null   timedelta64[ns]
#  1   AirTemp        4514 non-null   float64
#  2   Humidity       4514 non-null   float64
#  3   Pressure       4514 non-null   float64
#  4   Rainfall       4514 non-null   bool
#  5   TrackTemp      4514 non-null   float64
#  6   WindDirection  4514 non-null   int64
#  7   WindSpeed      4514 non-null   float64
#  8   raceId         4514 non-null   object
# dtypes: bool(1), float64(5), int64(1), object(1), timedelta64[ns](1)
# memory usage: 286.7+ KB

# %%
y2018_r13qualWeather
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:49.141000     24.7      58.8    1007.9     False       32.0
# 1  0 days 00:01:49.222000     24.7      58.8    1007.9     False       31.9
# 2  0 days 00:02:49.270000     24.8      58.9    1007.9     False       31.9
# 3  0 days 00:03:49.300000     24.7      58.9    1007.9     False       31.9
# 4  0 days 00:04:49.303000     24.6      59.3    1007.9     False       31.6
# ..                    ...      ...       ...       ...       ...        ...
# 73 0 days 01:13:51.003000     24.4      63.2    1007.9     False       28.9
# 74 0 days 01:14:50.151000     24.3      63.1    1007.9     False       28.8
# 75 0 days 01:15:50.329000     24.3      63.4    1007.9     False       28.9
# 76 0 days 01:16:50.182000     24.3      63.5    1007.9     False       29.0
# 77 0 days 01:17:50.198000     24.2      63.4    1007.9     False       29.1
#
#     WindDirection  WindSpeed    raceId
# 0             307        1.3  2018r13q
# 1             305        1.9  2018r13q
# 2             279        2.1  2018r13q
# 3             297        0.8  2018r13q
# 4             293        1.5  2018r13q
# ..            ...        ...       ...
# 73            252        0.5  2018r13q
# 74            166        0.7  2018r13q
# 75              4        0.3  2018r13q
# 76            265        0.7  2018r13q
# 77            356        0.8  2018r13q
#
# [78 rows x 9 columns]

# %%
all_qualResults
# Out:
#      DriverNumber BroadcastName Abbreviation         DriverId  \
# 0              44    L HAMILTON          HAM         hamilton
# 1               7   K RAIKKONEN          RAI        raikkonen
# 2               5      S VETTEL          VET           vettel
# 3              33  M VERSTAPPEN          VER   max_verstappen
# 4               3   D RICCIARDO          RIC        ricciardo
# ...           ...           ...          ...              ...
# 1155           10       P GASLY          GAS            gasly
# 1156           99  A GIOVINAZZI          GIO       giovinazzi
# 1157           63     G RUSSELL          RUS          russell
# 1158            6      N LATIFI          LAT           latifi
# 1159           20   K MAGNUSSEN          MAG  kevin_magnussen
#
#                TeamName TeamColor      TeamId  FirstName    LastName  \
# 0              Mercedes    00D2BE    mercedes      Lewis    Hamilton
# 1               Ferrari    DC0000     ferrari       Kimi   Räikkönen
# 2               Ferrari    DC0000     ferrari  Sebastian      Vettel
# 3       Red Bull Racing    1E41FF    red_bull        Max  Verstappen
# 4       Red Bull Racing    1E41FF    red_bull     Daniel   Ricciardo
# ...                 ...       ...         ...        ...         ...
# 1155         AlphaTauri    ffffff  alphatauri     Pierre       Gasly
# 1156  Alfa Romeo Racing    9B0000        alfa    Antonio  Giovinazzi
# 1157           Williams    0082fa    williams     George     Russell
# 1158           Williams    0082fa    williams   Nicholas      Latifi
# 1159       Haas F1 Team    787878        haas      Kevin   Magnussen
#
#                 FullName  ... Position ClassifiedPosition  GridPosition  \
# 0         Lewis Hamilton  ...      1.0                              NaN
# 1         Kimi Räikkönen  ...      2.0                              NaN
# 2       Sebastian Vettel  ...      3.0                              NaN
# 3         Max Verstappen  ...      4.0                              NaN
# 4       Daniel Ricciardo  ...      5.0                              NaN
# ...                  ...  ...      ...                ...           ...
# 1155        Pierre Gasly  ...     16.0                              NaN
# 1156  Antonio Giovinazzi  ...     17.0                              NaN
# 1157      George Russell  ...     18.0                              NaN
# 1158     Nicholas Latifi  ...     19.0                              NaN
# 1159     Kevin Magnussen  ...     20.0                              NaN
#
#                          Q1                     Q2                     Q3  \
# 0    0 days 00:01:22.824000 0 days 00:01:22.051000 0 days 00:01:21.164000
# 1    0 days 00:01:23.096000 0 days 00:01:22.507000 0 days 00:01:21.828000
# 2    0 days 00:01:23.348000 0 days 00:01:21.944000 0 days 00:01:21.838000
# 3    0 days 00:01:23.483000 0 days 00:01:22.416000 0 days 00:01:21.879000
# 4    0 days 00:01:23.494000 0 days 00:01:22.897000 0 days 00:01:22.152000
# ...                     ...                    ...                    ...
# 1155 0 days 00:01:17.125000                    NaT                    NaT
# 1156 0 days 00:01:17.220000                    NaT                    NaT
# 1157 0 days 00:01:17.232000                    NaT                    NaT
# 1158 0 days 00:01:17.320000                    NaT                    NaT
# 1159 0 days 00:01:17.348000                    NaT                    NaT
#
#      Time Status Points    raceId
# 0     NaT           NaN   2018r1q
# 1     NaT           NaN   2018r1q
# 2     NaT           NaN   2018r1q
# 3     NaT           NaN   2018r1q
# 4     NaT           NaN   2018r1q
# ...   ...    ...    ...       ...
# 1155  NaT           NaN  2020r21q
# 1156  NaT           NaN  2020r21q
# 1157  NaT           NaN  2020r21q
# 1158  NaT           NaN  2020r21q
# 1159  NaT           NaN  2020r21q
#
# [1160 rows x 22 columns]

# %%
all_raceTrackStatus
# Out:
#                       Time Status     Message    raceId
# 0   0 days 00:14:47.534000      2      Yellow   2018r1r
# 1   0 days 00:14:54.676000      1    AllClear   2018r1r
# 2   0 days 00:14:55.424000      2      Yellow   2018r1r
# 3   0 days 00:17:32.340000      1    AllClear   2018r1r
# 4   0 days 00:21:00.464000      2      Yellow   2018r1r
# ..                     ...    ...         ...       ...
# 553 0 days 01:14:11.784000      1    AllClear  2020r21r
# 554 0 days 02:05:40.977000      2      Yellow  2020r21r
# 555 0 days 02:05:54.264000      4  SCDeployed  2020r21r
# 556 0 days 02:09:44.391000      5         Red  2020r21r
# 557 0 days 02:28:01.392000      1    AllClear  2020r21r
#
# [558 rows x 4 columns]

# %%
#export to csv
dataframes = {
    "all_qualLaps": all_qualLaps,
    "all_qualWeather": all_qualWeather,
    "all_qualResults": all_qualResults,
    "all_qualStatus": all_qualStatus,
    "all_qualTrackStatus": all_qualTrackStatus,
    "all_raceLaps": all_raceLaps,
    "all_raceWeather": all_raceWeather,
    "all_raceResults": all_raceResults,
    "all_raceStatus": all_raceStatus,
    "all_raceTrackStatus": all_raceTrackStatus,
}

for name, df in dataframes.items():df.to_csv(f"{name}.csv", index=False)
